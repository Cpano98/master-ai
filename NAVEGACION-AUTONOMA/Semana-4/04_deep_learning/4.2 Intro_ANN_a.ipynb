# %% [markdown]
# ![header](https://drive.google.com/uc?export=view&id=1KuEspEp7OwqGw6uMRJvYE6BVE-Zo-8JF)
#
#  <h1> <div align="center"> Dr. David Antonio-Torres</div> </h1>

# %% [markdown]
# # Introducción a Redes Neuronales con Keras
# ### Usando Keras, se creará una neurona simple con dos pesos, un bias y la función sigmoid como función de activación.

# %% [markdown]
# # Modelo de una neurona

# %% [markdown]
# ![perceptron](https://drive.google.com/uc?export=view&id=1Z4GnmBVNU5Sdd0DJgs0aSkaeGYyUmDYz)
# ### https://platzi.com/tutoriales/1157-ia-2017/2619-entrenamiento-del-perceptron/

# %% [markdown]
# # Se cargan las bibliotecas necesarias

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Se hará uso de Keras para la programación de redes neuronales
import keras
# Sequential permite agregar capas de neuronas de manera secuencial
from keras.models import Sequential
# Dense crea redes neuronales completamente conectadas (fully connected)
from keras.layers imp ort Dense
from keras.optimizers import Adam

# %% [markdown]
# # Se carga como dataframe un dataset de prueba
# ### Las variables independientes son la altura del tope y distancia al tope
# ### La etiqueta es baja velocidad (0) o alta velocidad (1)

# %%
speed_data = pd.read_csv("speed_decision_data.csv")
speed_data.head()
# Out:
#    1 - Distance From Bump  Height of Bump  Speed
# 0                0.575374        0.680337      0
# 1                0.376002        0.278661      1
# 2                0.973890        0.741585      0
# 3                0.310378        0.342374      1
# 4                0.109521        0.268304      1

# %%
speed_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   1 - Distance From Bump  1000 non-null   float64
#  1   Height of Bump          1000 non-null   float64
#  2   Speed                   1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %% [markdown]
# # Se muestran los datos en una gráfica de dispersión

# %%
plt.figure()
sns.scatterplot(x= speed_data['1 - Distance From Bump'], y = speed_data['Height of Bump'], hue = speed_data['Speed'])
plt.show()

# %% [markdown]
# # Se crean los set de datos y etiquetas para entrenamiento
# ### En este ejemplo no hay set de prueba

# %%
X_train = speed_data[['1 - Distance From Bump', 'Height of Bump']]
y_train = speed_data['Speed']

# %% [markdown]
# # Se define la única neurona con Keras, dos entradas y una salida
# ### Sequential permite agregar capas de neuronas de manera secuencial
# ### La función de activación es Sigmoid
# ### La *loss function* es binaria dada la clasificación deseada
# ### El optimizador Adam es el recomendado
# ###

# %%
model = Sequential()
model.add(Dense(units=1, input_dim=2, activation='sigmoid'))
model.compile(optimizer=Adam(learning_rate=0.01), loss='binary_crossentropy',  metrics=['accuracy'])

# %% [markdown]
# ### Se entrena el modelo con 100 épocas, batch de 50 y shuffle activado

# %%
hist = model.fit(x=X_train, y=y_train, verbose=2, batch_size=50,epochs=100, shuffle='true')
# Out:
# Epoch 1/100
# 20/20 - 0s - 8ms/step - accuracy: 0.5030 - loss: 0.6057
# Epoch 2/100
# 20/20 - 0s - 593us/step - accuracy: 0.5440 - loss: 0.5742
# Epoch 3/100
# 20/20 - 0s - 585us/step - accuracy: 0.6730 - loss: 0.5439
# Epoch 4/100
# 20/20 - 0s - 555us/step - accuracy: 0.8070 - loss: 0.5153
# Epoch 5/100
# 20/20 - 0s - 581us/step - accuracy: 0.8860 - loss: 0.4886
# Epoch 6/100
# 20/20 - 0s - 522us/step - accuracy: 0.9300 - loss: 0.4636
# Epoch 7/100
# 20/20 - 0s - 588us/step - accuracy: 0.9620 - loss: 0.4402
# Epoch 8/100
# 20/20 - 0s - 535us/step - accuracy: 0.9780 - loss: 0.4184
# Epoch 9/100
# 20/20 - 0s - 532us/step - accuracy: 0.9850 - loss: 0.3983
# Epoch 10/100
# 20/20 - 0s - 512us/step - accuracy: 0.9880 - loss: 0.3791
# Epoch 11/100
# 20/20 - 0s - 534us/step - accuracy: 0.9880 - loss: 0.3617
# Epoch 12/100
# 20/20 - 0s - 542us/step - accuracy: 0.9950 - loss: 0.3451
# Epoch 13/100
# 20/20 - 0s - 523us/step - accuracy: 0.9960 - loss: 0.3298
# Epoch 14/100
# 20/20 - 0s - 540us/step - accuracy: 0.9960 - loss: 0.3152
# Epoch 15/100
# 20/20 - 0s - 574us/step - accuracy: 0.9970 - loss: 0.3017
# Epoch 16/100
# 20/20 - 0s - 547us/step - accuracy: 0.9980 - loss: 0.2889
# Epoch 17/100
# 20/20 - 0s - 572us/step - accuracy: 0.9980 - loss: 0.2770
# Epoch 18/100
# 20/20 - 0s - 568us/step - accuracy: 0.9990 - loss: 0.2658
# Epoch 19/100
# 20/20 - 0s - 559us/step - accuracy: 0.9990 - loss: 0.2552
# Epoch 20/100
# 20/20 - 0s - 552us/step - accuracy: 0.9990 - loss: 0.2453
# Epoch 21/100
# 20/20 - 0s - 549us/step - accuracy: 0.9990 - loss: 0.2360
# Epoch 22/100
# 20/20 - 0s - 549us/step - accuracy: 0.9990 - loss: 0.2272
# Epoch 23/100
# 20/20 - 0s - 544us/step - accuracy: 0.9990 - loss: 0.2190
# Epoch 24/100
# 20/20 - 0s - 535us/step - accuracy: 1.0000 - loss: 0.2113
# Epoch 25/100
# 20/20 - 0s - 566us/step - accuracy: 1.0000 - loss: 0.2039
# Epoch 26/100
# 20/20 - 0s - 575us/step - accuracy: 1.0000 - loss: 0.1969
# Epoch 27/100
# 20/20 - 0s - 580us/step - accuracy: 1.0000 - loss: 0.1903
# Epoch 28/100
# 20/20 - 0s - 587us/step - accuracy: 1.0000 - loss: 0.1841
# Epoch 29/100
# 20/20 - 0s - 548us/step - accuracy: 1.0000 - loss: 0.1782
# Epoch 30/100
# 20/20 - 0s - 552us/step - accuracy: 1.0000 - loss: 0.1726
# Epoch 31/100
# 20/20 - 0s - 560us/step - accuracy: 1.0000 - loss: 0.1672
# Epoch 32/100
# 20/20 - 0s - 633us/step - accuracy: 1.0000 - loss: 0.1622
# Epoch 33/100
# 20/20 - 0s - 592us/step - accuracy: 1.0000 - loss: 0.1573
# Epoch 34/100
# 20/20 - 0s - 564us/step - accuracy: 1.0000 - loss: 0.1527
# Epoch 35/100
# 20/20 - 0s - 545us/step - accuracy: 1.0000 - loss: 0.1483
# Epoch 36/100
# 20/20 - 0s - 603us/step - accuracy: 1.0000 - loss: 0.1441
# Epoch 37/100
# 20/20 - 0s - 584us/step - accuracy: 1.0000 - loss: 0.1401
# Epoch 38/100
# 20/20 - 0s - 554us/step - accuracy: 1.0000 - loss: 0.1362
# Epoch 39/100
# 20/20 - 0s - 511us/step - accuracy: 1.0000 - loss: 0.1326
# Epoch 40/100
# 20/20 - 0s - 626us/step - accuracy: 1.0000 - loss: 0.1291
# Epoch 41/100
# 20/20 - 0s - 564us/step - accuracy: 1.0000 - loss: 0.1257
# Epoch 42/100
# 20/20 - 0s - 576us/step - accuracy: 1.0000 - loss: 0.1225
# Epoch 43/100
# 20/20 - 0s - 538us/step - accuracy: 1.0000 - loss: 0.1194
# Epoch 44/100
# 20/20 - 0s - 570us/step - accuracy: 1.0000 - loss: 0.1164
# Epoch 45/100
# 20/20 - 0s - 555us/step - accuracy: 1.0000 - loss: 0.1136
# Epoch 46/100
# 20/20 - 0s - 580us/step - accuracy: 1.0000 - loss: 0.1109
# Epoch 47/100
# 20/20 - 0s - 552us/step - accuracy: 1.0000 - loss: 0.1082
# Epoch 48/100
# 20/20 - 0s - 590us/step - accuracy: 1.0000 - loss: 0.1057
# Epoch 49/100
# 20/20 - 0s - 568us/step - accuracy: 1.0000 - loss: 0.1032
# Epoch 50/100
# 20/20 - 0s - 555us/step - accuracy: 1.0000 - loss: 0.1009
# Epoch 51/100
# 20/20 - 0s - 512us/step - accuracy: 1.0000 - loss: 0.0986
# Epoch 52/100
# 20/20 - 0s - 583us/step - accuracy: 1.0000 - loss: 0.0965
# Epoch 53/100
# 20/20 - 0s - 528us/step - accuracy: 1.0000 - loss: 0.0943
# Epoch 54/100
# 20/20 - 0s - 512us/step - accuracy: 1.0000 - loss: 0.0923
# Epoch 55/100
# 20/20 - 0s - 531us/step - accuracy: 1.0000 - loss: 0.0903
# Epoch 56/100
# 20/20 - 0s - 534us/step - accuracy: 1.0000 - loss: 0.0884
# Epoch 57/100
# 20/20 - 0s - 514us/step - accuracy: 1.0000 - loss: 0.0866
# Epoch 58/100
# 20/20 - 0s - 553us/step - accuracy: 1.0000 - loss: 0.0848
# Epoch 59/100
# 20/20 - 0s - 628us/step - accuracy: 1.0000 - loss: 0.0831
# Epoch 60/100
# 20/20 - 0s - 509us/step - accuracy: 1.0000 - loss: 0.0815
# Epoch 61/100
# 20/20 - 0s - 530us/step - accuracy: 1.0000 - loss: 0.0798
# Epoch 62/100
# 20/20 - 0s - 524us/step - accuracy: 1.0000 - loss: 0.0783
# Epoch 63/100
# 20/20 - 0s - 507us/step - accuracy: 1.0000 - loss: 0.0768
# Epoch 64/100
# 20/20 - 0s - 511us/step - accuracy: 1.0000 - loss: 0.0753
# Epoch 65/100
# 20/20 - 0s - 540us/step - accuracy: 1.0000 - loss: 0.0739
# Epoch 66/100
# 20/20 - 0s - 510us/step - accuracy: 1.0000 - loss: 0.0725
# Epoch 67/100
# 20/20 - 0s - 517us/step - accuracy: 1.0000 - loss: 0.0712
# Epoch 68/100
# 20/20 - 0s - 552us/step - accuracy: 1.0000 - loss: 0.0699
# Epoch 69/100
# 20/20 - 0s - 529us/step - accuracy: 1.0000 - loss: 0.0687
# Epoch 70/100
# 20/20 - 0s - 524us/step - accuracy: 1.0000 - loss: 0.0674
# Epoch 71/100
# 20/20 - 0s - 747us/step - accuracy: 1.0000 - loss: 0.0663
# Epoch 72/100
# 20/20 - 0s - 1ms/step - accuracy: 1.0000 - loss: 0.0651
# Epoch 73/100
# 20/20 - 0s - 793us/step - accuracy: 1.0000 - loss: 0.0640
# Epoch 74/100
# 20/20 - 0s - 725us/step - accuracy: 1.0000 - loss: 0.0629
# Epoch 75/100
# 20/20 - 0s - 751us/step - accuracy: 1.0000 - loss: 0.0618
# Epoch 76/100
# 20/20 - 0s - 877us/step - accuracy: 1.0000 - loss: 0.0608
# Epoch 77/100
# 20/20 - 0s - 639us/step - accuracy: 1.0000 - loss: 0.0598
# Epoch 78/100
# 20/20 - 0s - 568us/step - accuracy: 1.0000 - loss: 0.0588
# Epoch 79/100
# 20/20 - 0s - 569us/step - accuracy: 1.0000 - loss: 0.0579
# Epoch 80/100
# 20/20 - 0s - 570us/step - accuracy: 1.0000 - loss: 0.0569
# Epoch 81/100
# 20/20 - 0s - 579us/step - accuracy: 1.0000 - loss: 0.0560
# Epoch 82/100
# 20/20 - 0s - 582us/step - accuracy: 1.0000 - loss: 0.0551
# Epoch 83/100
# 20/20 - 0s - 555us/step - accuracy: 1.0000 - loss: 0.0543
# Epoch 84/100
# 20/20 - 0s - 579us/step - accuracy: 1.0000 - loss: 0.0534
# Epoch 85/100
# 20/20 - 0s - 592us/step - accuracy: 1.0000 - loss: 0.0526
# Epoch 86/100
# 20/20 - 0s - 579us/step - accuracy: 1.0000 - loss: 0.0518
# Epoch 87/100
# 20/20 - 0s - 621us/step - accuracy: 1.0000 - loss: 0.0510
# Epoch 88/100
# 20/20 - 0s - 553us/step - accuracy: 1.0000 - loss: 0.0503
# Epoch 89/100
# 20/20 - 0s - 564us/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 90/100
# 20/20 - 0s - 606us/step - accuracy: 1.0000 - loss: 0.0488
# Epoch 91/100
# 20/20 - 0s - 539us/step - accuracy: 1.0000 - loss: 0.0481
# Epoch 92/100
# 20/20 - 0s - 558us/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 93/100
# 20/20 - 0s - 546us/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 94/100
# 20/20 - 0s - 510us/step - accuracy: 1.0000 - loss: 0.0461
# Epoch 95/100
# 20/20 - 0s - 545us/step - accuracy: 1.0000 - loss: 0.0454
# Epoch 96/100
# 20/20 - 0s - 552us/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 97/100
# 20/20 - 0s - 506us/step - accuracy: 1.0000 - loss: 0.0442
# Epoch 98/100
# 20/20 - 0s - 525us/step - accuracy: 1.0000 - loss: 0.0436
# Epoch 99/100
# 20/20 - 0s - 526us/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 100/100
# 20/20 - 0s - 512us/step - accuracy: 1.0000 - loss: 0.0424

# %%
# resumen del model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11 (48.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 8 (36.00 B)

# %% [markdown]
# # Se grafican el error y la exactitud del modelo

# %%
plt.plot(hist.history['accuracy']) 
plt.legend(['Exactitud'])
plt.ylabel('Exactitud')
plt.xlabel('Epoca')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.legend(['Error'])
plt.title('Error')
plt.xlabel('Epoca')
plt.show()

# %% [markdown]
# # Se visualizan los resultados del entrenamiento

# %%
from matplotlib.colors import ListedColormap
X_grid, y_grid = X_train.values, y_train.values

X1, X2 = np.meshgrid(np.arange(start = X_grid[:, 0].min() , stop = X_grid[:, 0].max(), step = 0.01),
                     np.arange(start = X_grid[:, 1].min(), stop = X_grid[:, 1].max(), step = 0.01))

plt.contourf(X1, X2, model.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))

plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_grid)):
    plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
    
plt.title('Resultados de la Clasificación')
plt.xlabel('Distancia del Tope')
plt.ylabel('Altura del Tope')
plt.legend()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step
# /var/folders/w6/304l7tqs0f946cfnk4fb4vg80000gp/T/ipykernel_34998/1057202357.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(X_grid[y_grid == j, 0], X_grid[y_grid == j, 1],

# %% [markdown]
# # Se imprimen los parámetros del modelo
# ### Layer 0 es la primera y única neurona del modelo

# %%
weights, biases = model.layers[0].get_weights()
print(weights)
print(biases)
# Out:
# [[-6.885342]
#  [-8.33927 ]]
# [7.0976186]

# %% [markdown]
# # Se somete a prueba el modelo con un dato arbitrario

# %%
dist = 0.7
alt = 0.7
dato = np.array([[dist, alt]])
prediccion = model.predict(dato)
print("Resultado: ",prediccion)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Resultado:  [[0.02766291]]

# %% [markdown]
# # Gracias por la atención
