# %%
import pika
import sys


credenciales = pika.PlainCredentials("czthkmld", "1oh50I65aKmnyHQFokVkEnLBOOoGRfBJ")

connection = pika.BlockingConnection(
    pika.ConnectionParameters(host="shrimp-01.rmq.cloudamqp.com",
    virtual_host="czthkmld",
    credentials=credenciales))

channel = connection.channel()

channel.exchange_declare(exchange='canal', exchange_type='topic')


result = channel.queue_declare('', exclusive=True)
queue_name = result.method.queue


binding_keys = ["#"]
for binding_key in binding_keys:
    channel.queue_bind(exchange='canal', queue=queue_name, routing_key="comunicacion")
    channel.queue_bind(exchange='canal', queue=queue_name, routing_key="logs")
    channel.queue_bind(exchange='canal', queue=queue_name, routing_key="raspberry")

print(' [*] Waiting for logs. To exit press CTRL+C')


def callback(ch, method, properties, body):
    print(f" [x] {method.routing_key}:{body}")
    #channel.basic_ack(delivery_tag=method.delivery_tag)


channel.basic_consume(
    queue=queue_name, on_message_callback=callback, auto_ack=True)

channel.start_consuming()
# Out:
#  [*] Waiting for logs. To exit press CTRL+C
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'0'
#  [x] raspberry:b'3'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'2'
#  [x] raspberry:b'3'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'1'
#  [x] raspberry:b'3'
#  [x] raspberry:b'0'
#  [x] raspberry:b'2'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'3'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'2'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'3'
#  [x] raspberry:b'2'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] raspberry:b'1'
#  [x] raspberry:b'0'
#  [x] comunicacion:b''
#  [x] comunicacion:b'comunicacion'
#  [x] comunicacion:b'holi'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 38
#      32     #channel.basic_ack(delivery_tag=method.delivery_tag)
#      35 channel.basic_consume(
#      36     queue=queue_name, on_message_callback=callback, auto_ack=True)
# ---> 38 channel.start_consuming()
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:1883, in BlockingChannel.start_consuming(self)
#    1880 # Process events as long as consumers exist on this channel
#    1881 while self._consumer_infos:
#    1882     # This will raise ChannelClosed if channel is closed by broker
# -> 1883     self._process_data_events(time_limit=None)
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:2044, in BlockingChannel._process_data_events(self, time_limit)
#    2025 def _process_data_events(self, time_limit):
#    2026     """Wrapper for `BlockingConnection.process_data_events()` with common
#    2027     channel-specific logic that raises ChannelClosed if broker closed this
#    2028     channel.
#    (...)
#    2042
#    2043     """
# -> 2044     self.connection.process_data_events(time_limit=time_limit)
#    2045     if self.is_closed and isinstance(self._closing_reason,
#    2046                                      exceptions.ChannelClosedByBroker):
#    2047         LOGGER.debug('Channel close by broker detected, raising %r; %r',
#    2048                      self._closing_reason, self)
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:842, in BlockingConnection.process_data_events(self, time_limit)
#     838 common_terminator = lambda: bool(dispatch_acquired and
#     839                                  (self._channels_pending_dispatch or
#     840                                   self._ready_events))
#     841 if time_limit is None:
# --> 842     self._flush_output(common_terminator)
#     843 else:
#     844     with _IoloopTimerContext(time_limit, self._impl) as timer:
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/blocking_connection.py:514, in BlockingConnection._flush_output(self, *waiters)
#     512 # Process I/O until our completion condition is satisfied
#     513 while not is_done():
# --> 514     self._impl.ioloop.poll()
#     515     self._impl.ioloop.process_timeouts()
#     517 if self._closed_result.ready:
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/select_connection.py:579, in IOLoop.poll(self)
#     572 def poll(self):
#     573     """[Extension] Wait for events of interest on registered file
#     574     descriptors until an event of interest occurs or next timer deadline or
#     575     `_PollerBase._MAX_POLL_TIMEOUT`, whichever is sooner, and dispatch the
#     576     corresponding event handlers.
#     577
#     578     """
# --> 579     self._poller.poll()
#
# File /opt/anaconda3/envs/master-ai-tec/lib/python3.12/site-packages/pika/adapters/select_connection.py:1064, in KQueuePoller.poll(self)
#    1062 while True:
#    1063     try:
# -> 1064         kevents = self._kqueue.control(None, 1000, self._get_max_wait())
#    1065         break
#    1066     except _SELECT_ERRORS as error:
#
# KeyboardInterrupt:
